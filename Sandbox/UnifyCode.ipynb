# %% [markdown]
# 6/23/2022
#
# In this notebook, I want to try to combine the "Energy Levels" and "Vibronic Manifolds" modules that I've written somewhat separately. The goal is to unify the type structures used in my simulations.

# %% [markdown]
# ### Type definitions

# %% [markdown]
# First of all, need to define the relevant types. I am going to try to do this by defining the types: `Hamiltonian`, `Eigenstate`, and `HamiltonianBlock`.

# %%
using Revise

# %%
using JuliaSpectra
using LinearAlgebra
using Parameters

# %%
bounds = (l=[-1,1], J = 1/2:5/2, I=1/2, N=1:4, Λ=0, S = 1/2)
basisX = enumerate_states(LinearCaseB_Bend_Field, bounds)
;

# %%
@unpack B, γ, bF, c,qv = MolParams["SrOH"]["X010"]
const BX = B
const γX = γ
const bFX = bF
const cX = c
const qvX=qv
;
# Out:
# WARNING: redefinition of constant BX. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant γX. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant bFX. This may fail, cause incorrect answers, or produce other errors.
# WARNING: redefinition of constant cX. This may fail, cause incorrect answers, or produce other errors.

# %%
xstate = makevibronicmanifold(basisX, [(BX, Rotation),(γX,SpinRotation),(bFX+cX/3, HyperfineFermi),(cX/3,Hyperfine_Dipolar_c),(qvX,lDoubling)])
;

# %%
xb,_ = makeblockedvibronicmanifold(xstate; block_fully = false)
;

# %%
eigsys = Eigenstate[]
for i = 1:length(xb.evals)
    push!(eigsys,Eigenstate(xb.evals[i], xb.evecs[:,i], xb.basis))
end

# %%
@with_kw struct Eigensystem{T<:BasisState}
    basis::Vector{T}
    H::Array{Float64,2}
    states::Vector{Eigenstate}
end
# Out:
# Eigensystem

# %%
hb = Eigensystem(basis=basisX, H=xb.H, states = eigsys)
# Out:
# Eigensystem{LinearCaseB_Bend_Field}
#   basis: Array{LinearCaseB_Bend_Field}((88,))
#   H: Array{Float64}((88, 88)) [0.2473954854682798 0.0 … 0.0 0.0; 0.0 0.24736817151057336 … 0.0 0.0; … ; 0.0 0.0 … 2.7299505773812682 0.0; 0.0 0.0 … 0.0 2.7299505773812682]
#   states: Array{Eigenstate}((88,))

# %%
hb.states
# Out:
# 88-element Vector{Eigenstate}:
#  E = 0.246968
#   0.0366 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0669 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.7029 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# -0.0012 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# -0.0126 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
# -0.0366 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.0669 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.7029 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.0012 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.0126 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
#
#  E = 0.246968
#   0.4428 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.5504 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.0294 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# -0.008 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0099 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# -0.4428 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.5504 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.0294 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.008 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# -0.0099 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
#
#  E = 0.246968
#   -0.55 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.4387 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.0704 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.0099 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0079 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# -0.0013 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.55 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.4387 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.0704 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# -0.0099 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# -0.0079 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.0013 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
#
#  E = 0.246995
#   -0.7071 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 0.0, M = 0.0>
# + 0.7071 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 0.0, M = 0.0>
#
#  E = 0.247768
#   0.6859 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.1711 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.0088 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# -0.0123 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0031 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.6859 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.1711 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.0088 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# -0.0123 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0031 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
#
#  E = 0.247768
#   -0.171 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.6859 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.0092 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.0031 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0123 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# -0.171 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.6859 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.0092 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.0031 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0123 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
#
#  E = 0.247768
#   -0.0107 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.0069 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.7069 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.0127 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
# -0.0107 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.0069 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.7069 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.0127 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
#
#  E = 0.247795
#   -0.7071 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 0.0, M = 0.0>
# -0.7071 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 0.0, M = 0.0>
#
#  E = 0.248752
#   -0.0111 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0061 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.6198 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.3397 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.0174 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.0111 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.0061 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.6198 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# -0.3397 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# -0.0174 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
#
#  E = 0.248752
#   -0.0061 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# -0.0111 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# -0.3395 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# -0.62 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.0108 |Λ = 0.0, l = -1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
# + 0.0061 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.0111 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 0.5, I = 0.5, F = 1.0, M = 0.0>
# + 0.3395 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = -1.0>
# + 0.62 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 0.0>
# -0.0108 |Λ = 0.0, l = 1.0, N = 1.0, S = 0.5, J = 1.5, I = 0.5, F = 1.0, M = 1.0>
#
#  ⋮
#  E = 2.732351
#   -0.7066 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -3.0>
# + 0.007 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -2.0>
# + 0.0047 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 1.0>
# -0.0078 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 2.0>
# + 0.0229 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 3.0>
# -0.7066 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -3.0>
# + 0.007 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -2.0>
# + 0.0047 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 1.0>
# -0.0078 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 2.0>
# + 0.0229 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 3.0>
#
#  E = 2.732351
#   0.023 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -3.0>
# -0.0987 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -2.0>
# + 0.0457 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -1.0>
# + 0.2112 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 1.0>
# -0.1247 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 2.0>
# + 0.6538 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 3.0>
# + 0.023 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -3.0>
# -0.0987 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -2.0>
# + 0.0457 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -1.0>
# + 0.2112 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 1.0>
# -0.1247 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 2.0>
# + 0.6538 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 3.0>
#
#  E = 2.732351
#   -0.0023 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -3.0>
# + 0.0523 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -2.0>
# + 0.1078 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -1.0>
# -0.1032 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 1.0>
# + 0.67 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 2.0>
# + 0.1615 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 3.0>
# -0.0023 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -3.0>
# + 0.0523 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -2.0>
# + 0.1078 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = -1.0>
# -0.1032 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 1.0>
# + 0.67 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 2.0>
# + 0.1615 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 3.0>
#
#  E = 2.732351
#   -0.7071 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 0.0>
# -0.7071 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 3.0, M = 0.0>
#
#  E = 2.732378
#   -0.5582 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# + 0.3452 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# -0.0174 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# + 0.0013 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
# + 0.2625 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 2.0>
# -0.5582 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# + 0.3452 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# -0.0174 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# + 0.0013 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
# + 0.2625 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 2.0>
#
#  E = 2.732378
#   0.3318 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# + 0.0644 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# + 0.0028 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# -0.0015 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
# + 0.6211 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 2.0>
# + 0.3318 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# + 0.0644 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# + 0.0028 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# -0.0015 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
# + 0.6211 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 2.0>
#
#  E = 2.732378
#   0.2796 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# + 0.6135 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# -0.0117 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# -0.0021 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
# -0.2129 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 2.0>
# + 0.2796 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# + 0.6135 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# -0.0117 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# -0.0021 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
# -0.2129 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 2.0>
#
#  E = 2.732378
#   0.0072 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# -0.016 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# -0.5869 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# -0.394 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
# + 0.0072 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# -0.016 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# -0.5869 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# -0.394 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
#
#  E = 2.732378
#   0.008 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# -0.0091 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# -0.3938 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# + 0.5872 |Λ = 0.0, l = -1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
# + 0.008 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -2.0>
# -0.0091 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = -1.0>
# -0.3938 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 0.0>
# + 0.5872 |Λ = 0.0, l = 1.0, N = 3.0, S = 0.5, J = 2.5, I = 0.5, F = 2.0, M = 1.0>
